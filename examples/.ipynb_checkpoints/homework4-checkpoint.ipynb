# %% [markdown]
# # Homework 4
# Jonah Spicher

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import classes from thinkbayes2
from thinkbayes2 import Pmf, Suite, Joint, NormalPdf, MakeMixture, MakeJoint

import thinkplot
import math
import numpy as np
from scipy.stats import norm

# %% [markdown]
# ### Height Problem
# The solution code was a lot prettier than mine so I definitely borrowed some of it. Sorry.

# %%
dist_height = dict(male=norm(178, 7.7),
                   female=norm(163, 7.3))
h_distribution = dict(male=norm(178, 7.7),
                   female=norm(163, 7.3))
hs = np.linspace(130, 210)
ps = dist_height['male'].pdf(hs)
male_height_pmf = Pmf(dict(zip(hs, ps)));
ps = dist_height['female'].pdf(hs)
female_height_pmf = Pmf(dict(zip(hs, ps)));
thinkplot.Pdf(male_height_pmf)
thinkplot.Pdf(female_height_pmf)

# %%
metapmf = Pmf({male_height_pmf:0.49, female_height_pmf:0.51})
mix = MakeMixture(metapmf)
thinkplot.Pdf(mix)

# %%
class Heights(Suite, Joint):
    
    def Likelihood(self, data, hypo):
        """
        
        data: 'A' or 'B' is taller
        hypo: height of 1, 
        """
        h1, h2 = hypo
        if data == 'A':
            return 1 if h1 > h2 else 0
        else:
            return 1 if h2 > h1 else 0

# %%
def make_prior(A, B):
    suite = Heights()

    for h1, p1 in A.Items():
        for h2, p2 in B.Items():
            suite[h1, h2] = p1 * p2
    return suite

def faceoff(player1, player2, data):
    """Compute the posterior distributions for both players.
    
    player1: Pmf
    player2: Pmf
    data: margin by which player1 beats player2
    """
    joint = make_prior(player1, player2)
    joint.Update(data)
    return joint.Marginal(0), joint.Marginal(1)

# %%
A = mix
B = mix
for i in range(8):
    A, _ = faceoff(A, B, 'A')
    
A, B = faceoff(A, B, 'B');

thinkplot.Pdf(A)
A.Mean()
# Out:
# 181.60660153115964

# %% [markdown]
# ### Lincoln Index Problem
# My solution seems to agree with the lincoln index pretty well, though I am concerned that it might not take into account the possibility that one tester is better than the other.

# %%
from scipy.special import binom

class Bugs(Suite):
    def Likelihood(self, data, hypo):
        """Computes the likelihood of the data under the hypothesis.

        hypo: total bugs (N)
        data: # caught by first tester (K), # caught by second tester (n), # caught by both (k)
        """
        N = hypo
        K, n, k = data

        if hypo < K + (n - k):
            return 0

        like = binom(N-K, n-k) / binom(N, n)
        return like

# %%
hypos = range(0, 201)
suite = Bugs(hypos)

data = 20, 1, 1
suite.Update(data)
thinkplot.plot(suite)
suite.MAP()
# Out:
# 20

# %%
def lincoln_index(n1, n2, c):
    return n1*n2/c

# %%
lincoln_index(20, 1, 1)
# Out:
# 20.0

# %% [markdown]
# ### Skeet Problem
# It should be fair to represent each shooter as a beta distribution, where heads and tails are hits and misses.

# %%
from thinkbayes2 import Beta
rhode = Beta(1, 1)
meng = Beta(1, 1)
r_hits = 15+1+2+2+2
r_misses = 10+1
m_hits = 15+1+2+2+1
m_misses = 10+1+1
rhode.Update((r_hits, r_misses))
meng.Update((m_hits, m_misses))
rhode = rhode.MakePmf()
meng = meng.MakePmf()
thinkplot.plot(rhode, color='grey')
thinkplot.plot(meng)

# %% [markdown]
# Then, we can pit the shooters against eachother in several thousand matches, until they converge on a defintie overall winner.

# %%
import random
def flip(p):
    return True if random.random() < p  else False

def rematch(r, m, num_matches):
    outcomes = [0, 0, 0] # rwins, mwins, ties
    for i in range(num_matches):
        r_total = 0
        m_total = 0
        
        r_ps = r.Sample(25)
        m_ps = m.Sample(25)
        
        for i in range(25):
            
            if flip(r_ps[i]):
                r_total += 1
            if flip(m_ps[i]):
                m_total += 1
        if r_total > m_total:
            outcomes[0] += 1
        elif r_total < m_total:
            outcomes[1] += 1
        else:
            outcomes[2] += 1
    return outcomes

# %%
num_matches = 100000
outcomes = rematch(rhode, meng, num_matches)
# Out:
# [52695, 35831, 11474]

# %%
r_winrate = outcomes[0] / num_matches
m_winrate = outcomes[1] / num_matches
tie_rate = outcomes[2] / num_matches
print(r_winrate, m_winrate)
# Out:
# 0.52695 0.35831

# %% [markdown]
# It looks like in the longterm, rhode will win more games than meng, though that is largely because a large portion of their games end in tied. Rhode only wins a little more than half of the time.

# %% [markdown]
# ### Social Desirability Problem
# Here, I started with a distribution of the number of people who flipped heads. Then, I found the likelihood as the total probability of the data given the hypothesis as a weighted sum for each possible number of heads. This required assuming a prior prevalence of atheists, but considering this was in a group of 100 people, that seems fair. The number seems a little low, though, as a quick guess says that because approximately half of the group should flip heads, the fraction of the remainder that answers no should be representative of the whole.

# %%
from thinkbayes2 import MakeBinomialPmf
heads_dist = MakeBinomialPmf(100, 0.5)
thinkplot.plot(heads_dist)

# %%
p_atheist = 0.2 # A guess about the prevalence of atheists overall. Wouldn't work if we were actually estimating
                # the frequency of atheists overall, but here it should be roughly true.
class Survey(Suite):
    def Likelihood(self, data, hypo):
        """
        data: number of people who answered 'yes'
        hypo: number of people we think are atheists
        """
        total = 0
        for num, p_heads in heads_dist.Items(): # Iterate through the possible numbers of heads and how likely that is    
            if data < num: # First, check to see if this is possible. Everyone who flipped heads had to say yes.
                p_data = 0
            else:
                num_known_atheists = 100 - data # Anyone who didn't say yes is definitely an atheist
                predicted_atheists = hypo - num_known_atheists # Our hypothesis is that there is an extra amount of atheists in the group that 
                if hypo < num_known_atheists: # If the data says there are more atheists than we think there are, then P(D|H) = 0
                    p_data = 0
                else:
                    atheist_dist = MakeBinomialPmf(num, p_atheist) # This is a distribution for how many of the people who flipped coins are atheists
                    p_data = atheist_dist[predicted_atheists] # This is that distribution, evaluated at the predicted number of atheists
                
            total += p_heads * p_data
        return total

# %%
people = Survey(range(0, 101))
people.Update(80)
thinkplot.plot(people)
people.Mean()
# Out:
# 29.99999999915436

# %% [markdown]
# ### Volunteer Problem
# This definitely still seems wrong, and my solution is admittedly pretty janky, but I am not sure how to fix it.

# %%
class first_update_volunteers(Suite, Joint):
    def Likelihood(self, data, hypo):
        """
        data: number reported back
        hypo: a tuple: (prob participating, prob reporting back)
        """
        q, r = hypo
        report_dist = MakeBinomialPmf(140, r) # Get a binomial distribution for current hypothetical r
        partic_dist = MakeBinomialPmf(140, q) # Get a binomial distribution for current hypothetical q
        like = report_dist[data] * partic_dist[data] # Multiply them both called for the data
        
        return like

# %%
ps = np.linspace(0, 1, num=100)
q_prior = Pmf(ps)
r_prior = Pmf(ps)
prior = MakeJoint(q_prior, r_prior) # Sets up an even prior
prior = first_update_volunteers(prior)
prior.Update(50) # Updates given that we know fifty people reported back
thinkplot.Contour(prior)
# Out:
# /home/jonah/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   s)

# %%
q = prior.Marginal(0)
r = prior.Marginal(1)
thinkplot.plot(q)
thinkplot.plot(r)

# %%
class second_update_volunteers(Suite, Joint):
    def Likelihood(self, data, hypo):
        """
        data: a tuple: (total, number participated, number reported back)
        hypo: a tuple: (prob participating, prob reporting back)
        """
        total, num_q, num_r = data
        q, r, = hypo
        report_dist = MakeBinomialPmf(total, r) # Makes a distribution for what we would expect to see for
        partic_dist = MakeBinomialPmf(total, q) # five random people we call
        p_q = partic_dist[num_q] 
        p_r = partic_dist[num_r]
        like = p_q * p_r # Just like the first likelihood function, updates given these probabilities
        return like

# %%
post = second_update_volunteers(prior)
post.Update((5, 3, 1))
thinkplot.Contour(post)
# Out:
# /home/jonah/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   s)

# %%
q = post.Marginal(0)
r = post.Marginal(1)
thinkplot.plot(q)
thinkplot.plot(r)

# %% [markdown]
# ### Project Ideas
#
# 1. Civilization win rates based on starting factors, similar to what is done [here](https://civscience.wordpress.com/)
#
# 2. Not sure if this counts as a pitch because you posted it, but estimating the number of atheists in the US looked like an intersting problem.
#
# 3. Something in linguistics, an example that's maybe silly is guessing what language an unknown word is based on the letters or phonemes it contains. Alternatively, something with Grimms law (and the equivalent for other languages) and finding the likelihood that different words come from Proto-Indo-European (this is based on sound shifts different languages underwent, some reading [here](https://en.wikipedia.org/wiki/Proto-Indo-European_language) and [here](https://en.wikipedia.org/wiki/Comparative_method) if you are curious). This is almost defintiely overscoped though, even if statistical methods can even be applied here.
